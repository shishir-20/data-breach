# %%
import pandas as pd
import joblib

model = joblib.load("../model/leakage_model.pkl")
label_encoder = joblib.load("../model/label_encoder.pkl")

print("✅ pandas, model, and encoder loaded")
# Out:
# ✅ pandas, model, and encoder loaded

# %%
new_file = pd.DataFrame([{
    "content_length": 7000,
    "contains_email": 1,
    "contains_pan": 0,
    "contains_aadhaar": 0,
    "file_type_encoded": 1
}])

new_file
# Out:
#    content_length  contains_email  contains_pan  contains_aadhaar  \
# 0            7000               1             0                 0
#
#    file_type_encoded
# 0                  1
