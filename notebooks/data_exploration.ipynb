# %%
import pandas as pd

df = pd.read_csv("../data/raw_data.csv")
df
# Out:
#           file_name file_type  content_length  contains_email  contains_pan  \
# 0        report.pdf       PDF            1200               0             0
# 1       salary.xlsx     Excel            5000               1             1
# 2         users.csv       CSV            3000               1             0
# 3     bank_data.csv       CSV            8000               1             1
# 4         notes.txt      Text             400               0             0
# 5  employee_db.xlsx     Excel            9000               1             1
#
#    contains_aadhaar             label
# 0                 0            Public
# 1                 0      Confidential
# 2                 0          Internal
# 3                 1  Highly_Sensitive
# 4                 0            Public
# 5                 1  Highly_Sensitive
